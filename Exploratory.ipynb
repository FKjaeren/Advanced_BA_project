# %%
## Packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

import warnings
warnings.filterwarnings('ignore') # ignore warnings

# %%
# load data
category = 'Candy & Chocolate' # define category  
df_train = pd.read_csv('data/'+category+'/df_train.csv')
df_train.columns
# Out:
# Index(['avg_rating', 'num_ratings', 'description', 'title', 'also_buy', 'rank',
#        'also_view', 'price', 'title_length', 'description_length',
#        'description_sentiment'],
#       dtype='object')

# %%
num_features = ['avg_rating','num_ratings','also_buy','also_view','price','rank','title_length','description_length','description_sentiment']
plt.figure()
sns.pairplot(df_train[num_features],height=1.1, aspect=1.3)
plt.xticks(rotation=90)
plt.tight_layout
plt.show()

# %%
sns.heatmap(df_train[num_features].corr().round(2), cmap='Blues', annot=True).set_title('Correlation matrix')
plt.show()

# %%
df_train.describe()
# Out:
#          avg_rating   num_ratings      also_buy          rank     also_view  \
# count  29828.000000  29828.000000  29829.000000  29829.000000  29829.000000
# mean       0.774352      0.002331      0.101386      0.082458      0.109790
# std        0.263154      0.011956      0.230363      0.062923      0.234034
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.666667      0.000000      0.000000      0.033642      0.000000
# 50%        0.853597      0.000323      0.000000      0.070391      0.000000
# 75%        1.000000      0.001291      0.018598      0.117025      0.081146
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#               price  title_length  description_length  description_sentiment
# count  29829.000000  29829.000000        29829.000000           29829.000000
# mean       0.021727      0.130041            0.043721               0.629393
# std        0.023088      0.065277            0.050175               0.351981
# min        0.000000      0.000000            0.000000              -0.926000
# 25%        0.016508      0.088235            0.020354               0.421500
# 50%        0.021727      0.120098            0.033194               0.757900
# 75%        0.021727      0.156863            0.056972               0.936000
# max        1.000000      1.000000            1.000000               0.999600
