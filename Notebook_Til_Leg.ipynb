# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('data/metadata_df.csv')
df = df.drop(columns=['Unnamed: 0'])
print(df.columns)
# Out:
# /Users/frederikkjaer/opt/miniconda3/envs/SkoleBase/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3185: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# Index(['item', 'avg_rating', 'num_ratings', 'category', 'tech1', 'description',
#        'fit', 'title', 'also_buy', 'tech2', 'brand', 'feature', 'rank',
#        'also_view', 'main_cat', 'similar_item', 'price', 'details',
#        'timestamp'],
#       dtype='object')

# %%
sns.displot(x="avg_rating", data=df)
plt.show()

# %%
sns.countplot(x="category", data=df)
plt.show()
